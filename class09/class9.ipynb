# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Mutable & Immutable Objects

# %%
a: int = 6
def abc(num: int) -> None:
    print(f"The value of num is {num} and address is {id(num)}")
    num = 5
    print(f"The value of num is {num} and address is {id(num)}")

abc(a)
print(a)
b: int = 6
print(id(b))
# Out:
# The value of num is 6 and address is 140725840136792
# The value of num is 5 and address is 140725840136760
# 6
# 140725840136792

# %%
num_list: list[int] = [1, 2, 3, 4, 5]
def abc_list(num: list[int]) -> None:
    print(f"The value of num is {num} and address is {id(num)}")
    num.append(6)
    print(f"The value of num is {num} and address is {id(num)}")

abc_list(num_list)
print(num_list)
# Out:
# The value of num is [1, 2, 3, 4, 5] and address is 2109007483264
# The value of num is [1, 2, 3, 4, 5, 6] and address is 2109007483264
# [1, 2, 3, 4, 5, 6]

# %%
x = 10
print(f"Before the value of x is {x} and address is {id(x)}")
x += 5
print(f"After the value of x is {x} and address is {id(x)}")

num_list: list[int] = [1, 2, 3, 4, 5]
print(f"Before the value of num_list is {num_list} and address is {id(num_list)}")
num_list.append(5)
print(f"After the value of num_list is {num_list} and address is {id(num_list)}")
# Out:
# Before the value of x is 10 and address is 140725840136920
# After the value of x is 15 and address is 140725840137080
# Before the value of num_list is [1, 2, 3, 4, 5] and address is 2109007456256
# After the value of num_list is [1, 2, 3, 4, 5, 5] and address is 2109007456256

# %%
num_list: list[int] = [1, 2, 3, 4, 5]
def xyz(nums: list[int]) -> None:
    nums = [6,7,8,9,10]
    nums.append(11)
    print(f"Inside the function the value of nums is {nums} and address is {id(nums)}")

print(f"Before the value of num_list is {num_list} and address is {id(num_list)}")
xyz(num_list)
print(f"After the value of num_list is {num_list} and address is {id(num_list)}")
# Out:
# Before the value of num_list is [1, 2, 3, 4, 5] and address is 2109007483264
# Inside the function the value of nums is [6, 7, 8, 9, 10, 11] and address is 2109009177792
# After the value of num_list is [1, 2, 3, 4, 5] and address is 2109007483264

# %% [markdown]
# # Error Handing
# ```
#     try:
#         logic
#     except (error_class, error_class, ...error_class):
#         if Error accured then run
#     else:
#         if error not accured
#     finally:
#         always run
# ```

# %%
# Development Error - 1
# def abc(num: int) -> None:
#     print(f"The value of num is {num} and address is {id(num)}")
#     num = "Hello"

# Logical Error - 1
def abc(num:int)->None:
    print(num%2)

abc(15)
# Out:
# 1

# %%
# Runtime Error - 1
user_input: int = int(input("Enter a number: "))
def abc(num:int)->None:
    # print(num/0)
    print(num)

abc(user_input) # ZeroDivisionError: division by zero

# # Runtime Error - 2
# user_input2: str = input("Enter a number: ")
# def abc2(num:int)->None:
#     print(num)

# abc2(user_input2) # TypeError: unsupported operand type(s) for /: 'str' and 'int'
# Out:
# 10
# 19

# %%
try:
    user_input: int = int(input("Enter a number: "))
    def abc(num:int)->None:
        print(num/4)
        print(num)

    abc(user_input) # ZeroDivisionError: division by zero
except (ZeroDivisionError, ValueError):
    print("This is an Error")
# Out:
# 5.25
# 21

# %%
try:
    print(10/0)
except ZeroDivisionError:
    print("This is an Error")
li: list[int] = [1, 2, 3, 4, 5]

try:
    print(10/5)
    print(li[100])
    print(xyz)
except ZeroDivisionError:
    print("This is an Error")
except NameError:
    print("This is a Name Error")
except Exception as e:
    print(f"This is an Error {e}")

user_input: int = int(input("Enter a number: "))
try:
    print(li[user_input])
except Exception as e:
    print(f"This is an Error {e}")
# Out:
# This is an Error
# 2.0
# This is an Error list index out of range
# This is an Error list index out of range

# %%
class StudentCard:
    def __init__(self, name: str, age: int, roll_no: int) -> None:
        if age < 18 or age > 60:
            raise AgeError("Age should be between 18 and 60.")
        self.name = name
        self.age = age
        self.roll_no = roll_no

class AgeError(Exception):
    pass

student1 = StudentCard("Hijabie", 20, 1)
print(student1.name)
print(student1.age)
print(student1.roll_no)
# Out:
# Hijabie
# 20
# 1

# %% [markdown]
# # File Handling

# %%
data = open("abc.txt")
print(data.read())

# with method and mode of file handling:
with open("abc.txt","r") as file:
    print(file.read())

with open("abc.txt","w") as file:
    file.write("Hello World!")

with open("abc.txt","r") as file:
    print(file.read())

with open("abc.txt","r+") as file:
    print(file.read())
    file.write("Hello Hijabie!")
    file.seek(0)
    print(file.read())

with open("abc.txt","a") as file:
    file.write("Hello Ahsaan!")
    file.seek(0)

with open("abc.txt","r") as file:
    print(file.read())

with open("abc2.txt","a+") as file:
    file.write("Hello Ahsaan!\n")
    file.seek(0)
    print("File2 abc2.txt:")
    print(file.read())
# Out:
# Hello World!Hello Hijabie!Hello Ahsaan!
# Hello World!Hello Hijabie!Hello Ahsaan!
# Hello World!
# Hello World!
# Hello World!Hello Hijabie!
# Hello World!Hello Hijabie!Hello Ahsaan!
# File2 abc2.txt:
# Hello Ahsaan!
# Hello Ahsaan!
# Hello Ahsaan!
# Hello Ahsaan!
# Hello Ahsaan!
# Hello Hijabie!
# Hello Ahsaan!
# Hello Ahsaan!
# Hello Ahsaan!

# %%
# read csv file
import pandas as pd
df: pd.DataFrame = pd.read_csv("data.csv")
df
# Out:
#               Name   F.Name     education
# 0  M.Ahsaan Abbasi  M.Israr  Intermediate

# %%
# read excel file
df: pd.DataFrame = pd.read_excel("mydata.xlsx")
df
# Out:
#    id      name         education
# 0   0  M.Ahsaan      Intermediate
# 1   1   Hijabie    B.E in Physcis
# 2   2    Alizay  B.Sc in Pharmacy
# 3   3  Gossipie        IT Courses

# %%
import PyPDF2

def read_pdf(file_path:str)->list[str]:
    with open(file_path, "rb") as file:
        reader: PyPDF2.PdfReader = PyPDF2.PdfReader(file)
        text_content: list[str] = [page.extract_text() for page in reader.pages]
        return text_content

pages = read_pdf("mydata.pdf")
display(pages)
# Out:
# ["Understanding\nthese\nconcepts\nempowers\nde v elopers\nt o\nwrite\neﬃcient,\nmodular ,\nand\nscalable\ncode\nin\nP ython\nand\nGen\nA.I.\npr ojects!\n🌐\nY our\nsuppor t\nfuels\nmy\npassion\nfor\ncontinuous\nlearning\nand\ngr owth!\n🙌\nLet' s\nk eep\npushing\nboundaries\nand\nunlocking\nnew\npossibilities\nt ogether!\n💬🔥",
#  '🌟\nDa y\n6:\nExploring\nF unctions\nin\nDepth!\n🚀']

# %%
# Image Reader 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('office1.0.jpeg')
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import numpy as np
import wave
import sys

audio_file = wave.open("myvoice.wav","rb")
signals = audio_file.readframes(-1)
signals = np.frombuffer(signals, dtype=np.int16)
plt.figure(1)
plt.title("Iphone Ringtone")
plt.plot(signals)
plt.show()

# %%
import matplotlib.pyplot as plt
import soundfile as sf
import numpy as np
from typing import Tuple

def plot_audio_waveform(file_path: str) -> None:
    """
    Plot the waveform of an audio file.

    Parameters:
        file_path (str): Path to the audio file.
    """
    signals, sample_rate = read_audio(file_path)
    time = np.arange(0, len(signals)) / sample_rate
    plt.figure(figsize=(10, 4))
    plt.title("Audio Waveform")
    plt.plot(time, signals)
    plt.xlabel("Time (s)")
    plt.ylabel("Amplitude")
    plt.show()

def read_audio(file_path: str) -> Tuple[np.ndarray, int]:
    """
    Read audio file and return audio data and sample rate.

    Parameters:
        file_path (str): Path to the audio file.

    Returns:
        tuple[np.ndarray, int]: Tuple containing audio data and sample rate.
    """
    data, sample_rate = sf.read(file_path)
    return data, sample_rate

# Example usage:
plot_audio_waveform("myvoice.mp3")  # Change the file name to the path of your audio file

# %%
# 10-1. Learning Python: Open a blank file in your text editor and write a few
# lines summarizing what you’ve learned about Python so far. Start each line
# with the phrase In Python you can.... Save the file as learning_python.txt in the
# same directory as your exercises from this chapter. Write a program that reads
# the file and prints what you wrote three times. Print the contents once by reading in the entire file, once by looping over the file object, and once by storing
# the lines in a list and then working with them outside the with block.
with open("learning_python.txt","r") as files:
    for line in files.readlines():
        print(line)
# Out:
# In Python you can create a variable and assign a value to it.
#
# In Python you can create a function and call it.
#
# In Python you can create a class and instantiate it.

# %%
# 10-3. Guest: Write a program that prompts the user for their name. When they
# respond, write their name to a file called guest.txt.
# with open("guest.txt","a") as files:
#     names:str = input("Enter your name: ")
#     files.write(f"{names}\n")

# 10-4. Guest Book: Write a while loop that prompts users for their name. When
# they enter their name, print a greeting to the screen and add a line recording
# their visit in a file called guest_book.txt. Make sure each entry appears on a
# new line in the file.
with open("guest_book.txt","w+")as files:
    while True:
        names:str = input("Enter your name: ?")
        if names == "q":
            break
        files.write(f"{names}\n")
        files.seek(0)
        for line in files.readlines():
            print(line)

# 10-5. Programming Poll: Write a while loop that asks people why they like
# programming. Each time someone enters a reason, add their reason to a file
# that stores all the responses.
with open("programming_poll.txt","a+") as files:
    while True:
        reason:str = input("Why do you like programming? ")
        if reason == "q":
            break
        files.write(f"{reason}\n")
        files.seek(0)
        for line in files.readlines():
            print(line)
# Out:
# Gossipie
#
# huzzi

# %%
# 10-6. Addition: One common problem when prompting for numerical input
# occurs when people provide text instead of numbers. When you try to convert
# the input to an int, you’ll get a TypeError. Write a program that prompts for
# two numbers. Add them together and print the result. Catch the TypeError if
# either input value is not a number, and print a friendly error message. Test your
# program by entering two numbers and then by entering some text instead of a
# number.
def add(a:int,b:int)->int:
    return a+b

# try:
#     a_input = input("Enter a number")
#     b_input = input("Enter a number")
#     try: 
#         a = int(a_input)
#         b = int(b_input)
#     except ValueError:
#         raise TypeError("This is not a number")
#     sum = add(a,b)
#     print(sum)
# except TypeError as e:
#     print(f"{e}")

# 10-7. Addition Calculator: Wrap your code from Exercise 10-6 in a while loop
# so the user can continue entering numbers even if they make a mistake and
# enter text instead of a number
try:
    while True:
        a_input = input("Enter a number")
        b_input = input("Enter a number")
        try: 
            a = int(a_input)
            b = int(b_input)
        except ValueError:
            raise TypeError("This is not a number")
        sum = add(a,b)
        print(sum)
except TypeError as e:
    print(f"{e}")
# Out:
# 17
# 17
# 12
# This is not a number
